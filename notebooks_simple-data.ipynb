# %%
# Importar pandas

# %%
import pandas as pd

# %%
# Importar matplotlib para graficar

# %%
from matplotlib import pyplot as plt

# %%
# Definir listas y graficarlas a través de matplotlib

# %%
x = [1, 2, 3]
y = [1, 4, 9]
z = [10, 5, 0]
plt.plot(x, y)
plt.plot(x, z)
plt.title("X & Y Ejemplo")
plt.xlabel ("x")
plt.ylabel("y")
plt.legend(["este es Y", "este es Z"])
plt.show()

# %%
# Análisis de datos en Python

# %%
import pandas as pd

# %%
sample_data = pd.read_csv("sample_data.csv")

# %%
sample_data
# Out:
#    column_a  column_b  column_c
# 0         1         1        10
# 1         2         4         8
# 2         3         9         6
# 3         4        16         4
# 4         5        25         2

# %%
type(sample_data)
# Out:
# pandas.core.frame.DataFrame

# %%
sample_data.column_c
# Out:
# 0    10
# 1     8
# 2     6
# 3     4
# 4     2
# Name: column_c, dtype: int64

# %%
type(sample_data.column_c)
# Out:
# pandas.core.series.Series

# %%
sample_data.column_c.iloc[3]
# Out:
# 4

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(sample_data.column_a, sample_data.column_b)
plt.plot(sample_data.column_a, sample_data.column_c)
plt.show()

# %%
# dataframe fuente de datos

# %%
base = pd.read_csv("set1.csv")

# %%
base
# Out:
#            am  1942  VNM    19760462    Unnamed: 4  0.087  0.004   3.385  \
# 0     Vietnam  1943  VNM  20341380.0           NaN  0.062  0.003   2.769
# 1     Vietnam  1944  VNM  20939374.0           NaN    NaN    NaN   1.425
# 2     Vietnam  1945  VNM  21554949.0           NaN  0.004  0.000   0.616
# 3     Vietnam  1946  VNM  22188620.0           NaN  0.018  0.001   0.714
# 4     Vietnam  1947  VNM  22840920.0           NaN  0.018  0.001   0.711
# ..        ...   ...  ...         ...           ...    ...    ...     ...
# 624  Zimbabwe  2016  ZWE  14030338.0  2.096179e+10  0.639  0.046  10.738
# 625  Zimbabwe  2017  ZWE  14236599.0  2.194784e+10  0.678  0.048   9.582
# 626  Zimbabwe  2018  ZWE  14438812.0  2.271535e+10  0.697  0.048  11.854
# 627  Zimbabwe  2019  ZWE  14645473.0           NaN  0.697  0.048  10.949
# 628  Zimbabwe  2020  ZWE  14862927.0           NaN  0.697  0.047  10.531
#
#      -2.942  -46.5  ...  Unnamed: 50  Unnamed: 51  Unnamed: 52  Unnamed: 53  \
# 0    -0.615 -18.18  ...          NaN          NaN          NaN          NaN
# 1    -1.344 -48.54  ...          NaN          NaN          NaN          NaN
# 2    -0.810 -56.81  ...          NaN          NaN          NaN          NaN
# 3     0.099  16.05  ...          NaN          NaN          NaN          NaN
# 4    -0.004  -0.51  ...          NaN          NaN          NaN          NaN
# ..      ...    ...  ...          ...          ...          ...          ...
# 624  -1.488 -12.17  ...         0.02          NaN          NaN          NaN
# 625  -1.156 -10.77  ...         0.02          NaN          NaN          NaN
# 626   2.273  23.72  ...         0.02          NaN          NaN          NaN
# 627  -0.905  -7.64  ...         0.02          NaN          NaN          NaN
# 628  -0.418  -3.82  ...         0.03          NaN          NaN          NaN
#
#      Unnamed: 54  Unnamed: 55  Unnamed: 56  Unnamed: 57  Unnamed: 58  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 624         0.03          NaN       115.92        28.53        1.415
# 625         0.03          NaN       115.59        28.30        1.666
# 626         0.03          NaN       118.22        30.83        1.308
# 627         0.03          NaN       117.96        30.53        1.473
# 628         0.03          NaN          NaN          NaN          NaN
#
#      Unnamed: 59
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 624        13.18
# 625        17.39
# 626        11.04
# 627        13.45
# 628          NaN
#
# [629 rows x 60 columns]
